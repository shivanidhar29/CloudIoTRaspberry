# %% [markdown]
# <a href="https://colab.research.google.com/github/shivanidhar29/projects/blob/main/Dupont.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt

myAPIKey = '79fc3166e685d1fce583c5a0a5c9b71b'

stock = 'CSCO'
balanceStatements = requests.get(f"https://financialmodelingprep.com/api/v3/balance-sheet-statement/{stock}?apikey={myAPIKey}").json()

incomeStatements = requests.get(f'https://financialmodelingprep.com/api/v3/income-statement/{stock}?apikey={myAPIKey}').json()

# %%
#four recent years
print(balanceStatements[:4])
# Out:
# [{'date': '2021-07-31', 'symbol': 'CSCO', 'reportedCurrency': 'USD', 'cik': '0000858877', 'fillingDate': '2021-09-09', 'acceptedDate': '2021-09-09 16:39:49', 'calendarYear': '2021', 'period': 'FY', 'cashAndCashEquivalents': 9175000000, 'shortTermInvestments': 15343000000, 'cashAndShortTermInvestments': 24518000000, 'netReceivables': 10146000000, 'inventory': 1559000000, 'otherCurrentAssets': 2889000000, 'totalCurrentAssets': 39112000000, 'propertyPlantEquipmentNet': 2338000000, 'goodwill': 38168000000, 'intangibleAssets': 3619000000, 'goodwillAndIntangibleAssets': 41787000000, 'longTermInvestments': 0.0, 'taxAssets': 4360000000, 'otherNonCurrentAssets': 9900000000, 'totalNonCurrentAssets': 58385000000, 'otherAssets': 0.0, 'totalAssets': 97497000000, 'accountPayables': 2362000000, 'shortTermDebt': 2508000000, 'taxPayables': 801000000, 'deferredRevenue': 12148000000, 'otherCurrentLiabilities': 9239000000, 'totalCurrentLiabilities': 26257000000, 'longTermDebt': 9018000000, 'deferredRevenueNonCurrent': 10016000000, 'deferredTaxLiabilitiesNonCurrent': 0.0, 'otherNonCurrentLiabilities': 10931000000, 'totalNonCurrentLiabilities': 29965000000, 'otherLiabilities': 0.0, 'capitalLeaseObligations': 0.0, 'totalLiabilities': 56222000000, 'preferredStock': 0.0, 'commonStock': 42346000000, 'retainedEarnings': -654000000, 'accumulatedOtherComprehensiveIncomeLoss': -417000000, 'othertotalStockholdersEquity': 0.0, 'totalStockholdersEquity': 41275000000, 'totalLiabilitiesAndStockholdersEquity': 97497000000, 'minorityInterest': 0, 'totalEquity': 41275000000, 'totalLiabilitiesAndTotalEquity': 97497000000, 'totalInvestments': 0.0, 'totalDebt': 11526000000, 'netDebt': 2351000000, 'link': 'https://www.sec.gov/Archives/edgar/data/858877/000085887721000013/0000858877-21-000013-index.htm', 'finalLink': 'https://www.sec.gov/Archives/edgar/data/858877/000085887721000013/csco-20210731.htm'}, {'date': '2020-07-25', 'symbol': 'CSCO', 'reportedCurrency': 'USD', 'cik': '0000858877', 'fillingDate': '2020-09-03', 'acceptedDate': '2020-09-03 17:05:55', 'calendarYear': '2020', 'period': 'FY', 'cashAndCashEquivalents': 11809000000, 'shortTermInvestments': 17610000000, 'cashAndShortTermInvestments': 29419000000, 'netReceivables': 11723000000, 'inventory': 1282000000, 'otherCurrentAssets': 1149000000, 'totalCurrentAssets': 43573000000, 'propertyPlantEquipmentNet': 3374000000, 'goodwill': 33806000000, 'intangibleAssets': 1576000000, 'goodwillAndIntangibleAssets': 35382000000, 'longTermInvestments': 1278000000, 'taxAssets': 81000000, 'otherNonCurrentAssets': 11165000000, 'totalNonCurrentAssets': 51280000000, 'otherAssets': 0.0, 'totalAssets': 94853000000, 'accountPayables': 2218000000, 'shortTermDebt': 3005000000, 'taxPayables': 839000000, 'deferredRevenue': 11406000000, 'otherCurrentLiabilities': 8702000000, 'totalCurrentLiabilities': 25331000000, 'longTermDebt': 11578000000, 'deferredRevenueNonCurrent': 9040000000, 'deferredTaxLiabilitiesNonCurrent': 8837000000, 'otherNonCurrentLiabilities': 2147000000, 'totalNonCurrentLiabilities': 31602000000, 'otherLiabilities': 0.0, 'capitalLeaseObligations': 0.0, 'totalLiabilities': 56933000000, 'preferredStock': 0.0, 'commonStock': 41202000000, 'retainedEarnings': -2763000000, 'accumulatedOtherComprehensiveIncomeLoss': -519000000, 'othertotalStockholdersEquity': 0.0, 'totalStockholdersEquity': 37920000000, 'totalLiabilitiesAndStockholdersEquity': 94853000000, 'minorityInterest': 0, 'totalEquity': 37920000000, 'totalLiabilitiesAndTotalEquity': 94853000000, 'totalInvestments': 18888000000, 'totalDebt': 14583000000, 'netDebt': 2774000000, 'link': 'https://www.sec.gov/Archives/edgar/data/858877/000085887720000010/0000858877-20-000010-index.htm', 'finalLink': 'https://www.sec.gov/Archives/edgar/data/858877/000085887720000010/csco-2020725x10k.htm'}, {'date': '2019-07-27', 'symbol': 'CSCO', 'reportedCurrency': 'USD', 'cik': '0000858877', 'fillingDate': '2019-09-05', 'acceptedDate': '2019-09-05 17:17:18', 'calendarYear': '2019', 'period ...

# %%
fourYearBalanceStatement = balanceStatements[:4]
fourYearIncomeStatement = incomeStatements[:4]

# %%
#first fraction
profitability = []
#second fraction
assetTurnOver = []
#Third fraction
capitalStructure = []
returnOnEquity = []
dates=[]

# getting details

for i in range(0,4):
  dates.append(fourYearBalanceStatement[i]['date'])
  profitabilityValue = fourYearIncomeStatement[i]['netIncome']/fourYearIncomeStatement[i]['revenue']
  profitability.append(profitabilityValue)

  assetTurnOverValue = fourYearIncomeStatement[i]['revenue']/fourYearBalanceStatement[i]['totalAssets']
  assetTurnOver.append(assetTurnOverValue)
  capitalStructureValue = fourYearBalanceStatement[i]['totalAssets']/fourYearBalanceStatement[i]['totalStockholdersEquity']
  capitalStructure.append(capitalStructureValue)

  returnOnEquityValue = profitabilityValue * assetTurnOverValue * capitalStructureValue
  returnOnEquity.append(returnOnEquityValue)

# %%
print(returnOnEquity)
# Out:
# [0.2565960024227741, 0.29572784810126584, 0.3461618658961604, 0.0025460605499490786]

# %%
# creating a dataframe
df = pd.DataFrame(columns = ['date','profitability','assetTurnOver','CapitalStructure','returnOnEquity'])
#df['year'] = pd. DatetimeIndex(df['date']). year.

df['profitability'] = profitability
df['assetTurnOver'] = assetTurnOver
df['CapitalStructure'] = capitalStructure

df['returnOnEquity'] = returnOnEquity
df['date'] = dates


print(df)
# Out:
#          date  profitability  assetTurnOver  CapitalStructure  returnOnEquity
# 0  2021-07-31       0.212594       0.510970          2.362132        0.256596
# 1  2020-07-25       0.227460       0.519762          2.501398        0.295728
# 2  2019-07-27       0.223894       0.530754          2.913020        0.346162
# 3  2018-07-28       0.002230       0.453467          2.517915        0.002546

# %%
from IPython.core.pylabtools import figsize
fig, axs = plt.subplots(2, 2,figsize=(10,10))
x = df['date']
axs[0, 0].plot(x, df['profitability'])
axs[0, 0].set_title('Profitability')
axs[0, 1].plot(x, df['assetTurnOver'],'tab:green')
axs[0, 1].set_title('assetTurnOver')
axs[1, 0].plot(x, df['CapitalStructure'],'tab:orange')
axs[1, 0].set_title('CapitalStructure')
axs[1, 1].plot(x, df['returnOnEquity'], 'tab:red')
axs[1, 1].set_title('ReturnonEquity')

fig.tight_layout()
